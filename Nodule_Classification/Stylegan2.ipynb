# %%
# !stylegan2_pytorch --data "/Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png" \
    --image-size 64 \
    --num-train-steps 30000 \
    --batch-size 32 \
    --multi-gpus 
    --network-capacity 64
# Out:
# Python 3.6 has reached EOL. Aim support for Python 3.6 is deprecated!
# Python 3.6 support will be dropped in Aim version 3.16
# continuing from previous epoch - 0
# loading from version 1.8.9
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   0%| | 50/3G: 0.71 | D: 0.93 | GP: 90.15
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   0%| | 100/G: 1.45 | D: 1.25 | GP: 100.86
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   0%| | 150/G: 25.37 | D: 0.63 | GP: 0.82
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   1%| | 200/G: -2.32 | D: 1.65 | GP: 0.74
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   1%| | 250/G: -0.08 | D: 0.46 | GP: 0.03
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   1%| | 300/G: 1.50 | D: 0.76 | GP: 5.39
# default</Storage/PauloOctavioDir/nodule_rois/gan/adeno/images_png>:   1%| | 350/G: 1.59 | D: 1.07 | GP: 22.63
# ...
